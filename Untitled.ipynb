# %%
import pandas as pd
import seaborn as sborn
data=pd.read_csv('mecit.txt')
dt_copy=data.copy()
data
# Out:
#                    Time   Battery   PoorSignal   Attention   Meditation  \
# 0                     3     60003       874345           0          NaN
# 1       15:04:22.000265         0           26           0          0.0
# 2       15:04:22.000265         0           26           0          0.0
# 3       15:04:22.000265         0           26           0          0.0
# 4       15:04:22.000281         0           26           0          0.0
# ...                 ...       ...          ...         ...          ...
# 874969  15:34:06.000015         0            0          80         81.0
# 874970  15:34:06.000015         0            0          80         81.0
# 874971  15:34:06.000015         0            0          80         81.0
# 874972  15:34:06.000015         0            0          80         81.0
# 874973  15:34:06.000031         0            0          80         81.0
#
#            Raw     Delta     Theta   lowAlpha   highAlpha   lowBeta  \
# ...

# %%
data.shape #Veri seti 874974 satır ve 16 sütundan oluşuyor
# Out:
# (874974, 16)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874974 entries, 0 to 874973
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         874974 non-null  object
#  1    Battery     874974 non-null  int64
#  2    PoorSignal  874974 non-null  int64
#  3    Attention   874974 non-null  int64
#  4    Meditation  874973 non-null  float64
#  5    Raw         874973 non-null  float64
#  6    Delta       874973 non-null  float64
#  7    Theta       874973 non-null  float64
#  8    lowAlpha    874972 non-null  float64
#  9    highAlpha   874972 non-null  float64
#  10   lowBeta     874972 non-null  float64
#  11   highBeta    874972 non-null  float64
#  12   lowGamma    874972 non-null  float64
#  13   highGamma   874972 non-null  float64
#  14   Blink       874972 non-null  float64
#  15  Unnamed: 15  0 non-null       float64
# dtypes: float64(12), int64(3), object(1)
# memory usage: 106.8+ MB

# %%
data.isnull().values.any() #Veri setinde eksik deger varmı?
# Out:
# True

# %%
data.isnull().sum() #tüm değişkenlerdeki toplam eksik değer sayısını veri
# Out:
# Time                0
#  Battery            0
#  PoorSignal         0
#  Attention          0
#  Meditation         1
#  Raw                1
#  Delta              1
#  Theta              1
#  lowAlpha           2
#  highAlpha          2
#  lowBeta            2
#  highBeta           2
#  lowGamma           2
#  highGamma          2
#  Blink              2
# Unnamed: 15    874974
# dtype: int64

# %%
#ilerde unnamed Sütunu kaldıracağım

# %%
values= data.select_dtypes(include = ["object"]) #obje türündeki özellikler
values
# Out:
#                    Time
# 0                     3
# 1       15:04:22.000265
# 2       15:04:22.000265
# 3       15:04:22.000265
# 4       15:04:22.000281
# ...                 ...
# 874969  15:34:06.000015
# 874970  15:34:06.000015
# 874971  15:34:06.000015
# 874972  15:34:06.000015
# 874973  15:34:06.000031
#
# [874974 rows x 1 columns]

# %%
values2= data.select_dtypes(include = ["float64"])#sayısal özellikler
values2
# Out:
#          Meditation     Raw     Delta     Theta   lowAlpha   highAlpha  \
# 0               NaN     NaN       NaN       NaN        NaN         NaN
# 1               0.0  1424.0  515600.0  312710.0   129503.0    439264.0
# 2               0.0  -280.0  515600.0  312710.0   129503.0    439264.0
# 3               0.0 -1889.0  515600.0  312710.0   129503.0    439264.0
# 4               0.0 -2048.0  515600.0  312710.0   129503.0    439264.0
# ...             ...     ...       ...       ...        ...         ...
# 874969         81.0   252.0  420181.0  252953.0   122189.0     13822.0
# 874970         81.0   279.0  420181.0  252953.0   122189.0     13822.0
# 874971         81.0   226.0  420181.0  252953.0   122189.0     13822.0
# 874972         81.0   101.0  420181.0  252953.0   122189.0     13822.0
# 874973         81.0   -18.0  420181.0    2529.0        NaN         NaN
#
#          lowBeta   highBeta   lowGamma   highGamma   Blink  Unnamed: 15
# ...

# %%
values3= data.select_dtypes(include = ["int64"])#sayısal özellikler
values3
# Out:
#          Battery   PoorSignal   Attention
# 0          60003       874345           0
# 1              0           26           0
# 2              0           26           0
# 3              0           26           0
# 4              0           26           0
# ...          ...          ...         ...
# 874969         0            0          80
# 874970         0            0          80
# 874971         0            0          80
# 874972         0            0          80
# 874973         0            0          80
#
# [874974 rows x 3 columns]

# %% [markdown]
# # VERİ ÖN İŞLEME #

# %% [markdown]
# 1. İlk Olarak Gereksiz sutun olduğundan unnamend sütunundan filitrelencek
# 2. ilk satırdaki veriler silinecek
# 3. Battery sütunumuz işimize yaramayacağı için kaldıralacak

# %%
data.head()
# Out:
#               Time   Battery   PoorSignal   Attention   Meditation     Raw  \
# 0                3     60003       874345           0          NaN     NaN
# 1  15:04:22.000265         0           26           0          0.0  1424.0
# 2  15:04:22.000265         0           26           0          0.0  -280.0
# 3  15:04:22.000265         0           26           0          0.0 -1889.0
# 4  15:04:22.000281         0           26           0          0.0 -2048.0
#
#       Delta     Theta   lowAlpha   highAlpha   lowBeta   highBeta   lowGamma  \
# 0       NaN       NaN        NaN         NaN       NaN        NaN        NaN
# 1  515600.0  312710.0   129503.0    439264.0   82620.0   189073.0    60003.0
# 2  515600.0  312710.0   129503.0    439264.0   82620.0   189073.0    60003.0
# 3  515600.0  312710.0   129503.0    439264.0   82620.0   189073.0    60003.0
# 4  515600.0  312710.0   129503.0    439264.0   82620.0   189073.0    60003.0
#
#     highGamma   Blink  Unnamed: 15
# ...

# %%
# 'Unnamed' sütununu kaldır
data.drop(columns=['Unnamed: 15'], inplace=True)
data
# Out:
#                    Time   Battery   PoorSignal   Attention   Meditation  \
# 0                     3     60003       874345           0          NaN
# 1       15:04:22.000265         0           26           0          0.0
# 2       15:04:22.000265         0           26           0          0.0
# 3       15:04:22.000265         0           26           0          0.0
# 4       15:04:22.000281         0           26           0          0.0
# ...                 ...       ...          ...         ...          ...
# 874969  15:34:06.000015         0            0          80         81.0
# 874970  15:34:06.000015         0            0          80         81.0
# 874971  15:34:06.000015         0            0          80         81.0
# 874972  15:34:06.000015         0            0          80         81.0
# 874973  15:34:06.000031         0            0          80         81.0
#
#            Raw     Delta     Theta   lowAlpha   highAlpha   lowBeta  \
# ...

# %%
# İlk satırı sil
data.drop(data.index[0], inplace=True)
data
# Out:
#                    Time   Battery   PoorSignal   Attention   Meditation  \
# 1       15:04:22.000265         0           26           0          0.0
# 2       15:04:22.000265         0           26           0          0.0
# 3       15:04:22.000265         0           26           0          0.0
# 4       15:04:22.000281         0           26           0          0.0
# 5       15:04:22.000281         0           26           0          0.0
# ...                 ...       ...          ...         ...          ...
# 874969  15:34:06.000015         0            0          80         81.0
# 874970  15:34:06.000015         0            0          80         81.0
# 874971  15:34:06.000015         0            0          80         81.0
# 874972  15:34:06.000015         0            0          80         81.0
# 874973  15:34:06.000031         0            0          80         81.0
#
#            Raw     Delta     Theta   lowAlpha   highAlpha   lowBeta  \
# ...

# %%
# 'Battery' sütununu kaldır
data.drop(columns=[' Battery'], inplace=True)
data
# Out:
#                    Time   PoorSignal   Attention   Meditation     Raw  \
# 1       15:04:22.000265           26           0          0.0  1424.0
# 2       15:04:22.000265           26           0          0.0  -280.0
# 3       15:04:22.000265           26           0          0.0 -1889.0
# 4       15:04:22.000281           26           0          0.0 -2048.0
# 5       15:04:22.000281           26           0          0.0 -2048.0
# ...                 ...          ...         ...          ...     ...
# 874969  15:34:06.000015            0          80         81.0   252.0
# 874970  15:34:06.000015            0          80         81.0   279.0
# 874971  15:34:06.000015            0          80         81.0   226.0
# 874972  15:34:06.000015            0          80         81.0   101.0
# 874973  15:34:06.000031            0          80         81.0   -18.0
#
#            Delta     Theta   lowAlpha   highAlpha   lowBeta   highBeta  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874973 entries, 1 to 874973
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         874973 non-null  object
#  1    PoorSignal  874973 non-null  int64
#  2    Attention   874973 non-null  int64
#  3    Meditation  874973 non-null  float64
#  4    Raw         874973 non-null  float64
#  5    Delta       874973 non-null  float64
#  6    Theta       874973 non-null  float64
#  7    lowAlpha    874972 non-null  float64
#  8    highAlpha   874972 non-null  float64
#  9    lowBeta     874972 non-null  float64
#  10   highBeta    874972 non-null  float64
#  11   lowGamma    874972 non-null  float64
#  12   highGamma   874972 non-null  float64
#  13   Blink       874972 non-null  float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 93.5+ MB

# %%
import matplotlib.pyplot as plt
brain_signals = data[["Time", " Raw", " Delta", " Theta", " lowAlpha", " highAlpha", " lowBeta", " highBeta", " lowGamma", " highGamma"]]


# 'Time' sütununu indeks olarak ayarla
brain_signals.set_index('Time', inplace=True)

# Beyin sinyallerini görselleştir
plt.figure(figsize=(12, 6))
brain_signals.plot(ax=plt.gca())
plt.title('Beyin Sinyalleri')
plt.xlabel('Zaman')
plt.ylabel('Sinyal Değeri')
plt.grid(True)
plt.legend(loc='upper left')
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Time', 'PoorSignal', 'Attention', 'Meditation', 'Raw', 'Delta',
#        'Theta', 'lowAlpha', 'highAlpha', 'lowBeta', 'highBeta', 'lowGamma',
#        'highGamma', 'Blink'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()  # Boşlukları kaldır

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Boşlukları sütun adlarından kaldır
data.columns = data.columns.str.strip()

# Beyin sinyallerini seç
brain_signals = data[['Time', 'Raw', 'Delta', 'Theta', 'lowAlpha', 'highAlpha', 'lowBeta', 'highBeta', 'lowGamma']]

# Görüntü boyutunu ayarla ve grafik oluştur
plt.figure(figsize=(12, 6))

# Beyin sinyallerini 'Time' sütununa göre çiz
plt.plot(brain_signals['Time'], brain_signals.drop(columns=['Time']))

# Grafik başlığını ekle
plt.title('Beyin Sinyalleri')

# Eksen etiketlerini ekle
plt.xlabel('Zaman')
plt.ylabel('Sinyal Değeri')

# Eksenleri otomatik olarak ayarla
plt.autoscale(enable=True, axis='x', tight=True)
colors = ['blue', 'orange', 'green', 'red', 'purple', 'yellow', 'pink', 'gray']
labels = ['Raw', 'Delta', 'Theta', 'lowAlpha', 'highAlpha', 'lowBeta', 'highBeta', 'lowGamma']

# Görseli göster
plt.show()
# Out:
# KeyboardInterrupt

# %%
# 'Time' sütununu indeks olarak ayarla


# Beyin sinyallerini seç
brain_signals = data[['Raw', 'Delta', 'Theta', 'lowAlpha', 'highAlpha']]

# Grafik boyutunu ayarla
plt.figure(figsize=(12, 6))

# Beyin sinyallerini çiz
for column in brain_signals.columns:
    plt.plot(brain_signals.index, brain_signals[column], label=column)

# Grafik başlığı ve eksen etiketlerini ekle
plt.title('HUMAN BRAIN WAVES')
plt.xlabel('Time')
plt.ylabel('Amplitude')

# Izgara çizgilerini etkinleştir
plt.grid(True)

# Grafikteki beyin dalgalarını açıkla
plt.legend()

# Grafik göster
plt.show()

# %%
data
# Out:
#                   PoorSignal   Attention   Meditation     Raw     Delta  \
# Time
# 15:04:22.000281           26           0          0.0 -2048.0  515600.0
# 15:04:22.000281           26           0          0.0 -2048.0  515600.0
# 15:04:22.000281           26           0          0.0 -1101.0  515600.0
# 15:04:22.000281           26           0          0.0   405.0  515600.0
# 15:04:22.000281           26           0          0.0  1800.0  515600.0
# ...                      ...         ...          ...     ...       ...
# 15:34:06.000015            0          80         81.0   252.0  420181.0
# 15:34:06.000015            0          80         81.0   279.0  420181.0
# 15:34:06.000015            0          80         81.0   226.0  420181.0
# 15:34:06.000015            0          80         81.0   101.0  420181.0
# 15:34:06.000031            0          80         81.0   -18.0  420181.0
#
#                     Theta   lowAlpha   highAlpha   lowBeta   highBeta  \
# Time
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 874974 entries, 0 to 874973
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Time         874974 non-null  object
#  1    Battery     874974 non-null  int64
#  2    PoorSignal  874974 non-null  int64
#  3    Attention   874974 non-null  int64
#  4    Meditation  874973 non-null  float64
#  5    Raw         874973 non-null  float64
#  6    Delta       874973 non-null  float64
#  7    Theta       874973 non-null  float64
#  8    lowAlpha    874972 non-null  float64
#  9    highAlpha   874972 non-null  float64
#  10   lowBeta     874972 non-null  float64
#  11   highBeta    874972 non-null  float64
#  12   lowGamma    874972 non-null  float64
#  13   highGamma   874972 non-null  float64
#  14   Blink       874972 non-null  float64
#  15  Unnamed: 15  0 non-null       float64
# dtypes: float64(12), int64(3), object(1)
# memory usage: 106.8+ MB

# %%
data.reset_index(inplace=True)
data
# Out:
#                              Time  PoorSignal  Attention  Meditation     Raw  \
# 0      2024-03-07 15:04:22.000265          26          0         0.0  1424.0
# 1      2024-03-07 15:04:22.000265          26          0         0.0  -280.0
# 2      2024-03-07 15:04:22.000265          26          0         0.0 -1889.0
# 3      2024-03-07 15:04:22.000281          26          0         0.0 -2048.0
# 4      2024-03-07 15:04:22.000281          26          0         0.0 -2048.0
# ...                           ...         ...        ...         ...     ...
# 874968 2024-03-07 15:34:06.000015           0         80        81.0   252.0
# 874969 2024-03-07 15:34:06.000015           0         80        81.0   279.0
# 874970 2024-03-07 15:34:06.000015           0         80        81.0   226.0
# 874971 2024-03-07 15:34:06.000015           0         80        81.0   101.0
# 874972 2024-03-07 15:34:06.000031           0         80        81.0   -18.0
#
# ...

# %% [markdown]
#  # Not
#  Fourier donusumunun suanda nasil oldugunu bilmiyorum numpy kutuhanesinde bir fonksiyon calistirdim ne yaptigini bilmiyorum ancak satir sayisi cogaldi

# %%
# 'Time' sütununu datetime türüne dönüştür
data['Time'] = pd.to_datetime(data['Time'], format='%H:%M:%S.%f')
# diger turlu time sutununda problem cikardi


# 'Time' sütununu indeks olarak ayarla
data.set_index('Time', inplace=True)

# Örnekleme frekansını 256 Hz'ye düşür
downsampled_signals = data.resample('2S').mean()

# Fourier dönüşümünü uygula
fourier_transformed = np.fft.fft(downsampled_signals)
# Sonuçları incele
print(fourier_transformed)
# Out:
# [[ 3.04621020e+06      +0.j         -9.43716905e+05 -366081.85491981j
#   -7.57769501e+05+1357507.78135811j ...  3.63440999e+05 -567109.50372956j
#   -7.57769501e+05-1357507.78135811j -9.43716905e+05 +366081.85491981j]
#  [ 3.82306448e+06      +0.j         -1.36644824e+06-1177215.79205747j
#   -1.15979024e+06+2137593.28632532j ...  1.13216859e+06 -363367.20041227j
#   -1.15979024e+06-2137593.28632532j -1.36644824e+06+1177215.79205747j]
#  [ 2.63617956e+06      +0.j         -9.41020470e+05 -425651.28395395j
#   -5.37372585e+05+1373101.69192591j ...  4.13488278e+05  -57114.10800009j
#   -5.37372585e+05-1373101.69192591j -9.41020470e+05 +425651.28395395j]
#  ...
#  [ 1.97619120e+06      +0.j         -2.97238277e+05  -90241.65752763j
#   -5.82474839e+05+1279104.75277713j ... -9.27068782e+04 -132756.0613783j
#   -5.82474839e+05-1279104.75277713j -2.97238277e+05  +90241.65752763j]
#  [ 1.84994131e+06      +0.j         -1.89502997e+05  -10505.72741268j
# ...

# %%
data
# Out:
#                             PoorSignal  Attention  Meditation     Raw  \
# Time
# 2024-03-07 15:04:22.000265          26          0         0.0  1424.0
# 2024-03-07 15:04:22.000265          26          0         0.0  -280.0
# 2024-03-07 15:04:22.000265          26          0         0.0 -1889.0
# 2024-03-07 15:04:22.000281          26          0         0.0 -2048.0
# 2024-03-07 15:04:22.000281          26          0         0.0 -2048.0
# ...                                ...        ...         ...     ...
# 2024-03-07 15:34:06.000015           0         80        81.0   252.0
# 2024-03-07 15:34:06.000015           0         80        81.0   279.0
# 2024-03-07 15:34:06.000015           0         80        81.0   226.0
# 2024-03-07 15:34:06.000015           0         80        81.0   101.0
# 2024-03-07 15:34:06.000031           0         80        81.0   -18.0
#
#                                Delta     Theta  lowAlpha  highAlpha  lowBeta  \
# Time
# ...
